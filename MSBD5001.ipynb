# %%
import pandas as pd
import numpy as np
from sklearn import tree, metrics, linear_model
from sklearn.model_selection import train_test_split
from sklearn.tree.export import export_text
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures

# %%
def classify(x):
    if x<0.05:
        return 0
    elif x<10:
        return 1
    else:
        return 2

# %%
def preprocess(filename):
    df = pd.read_csv(filename,parse_dates = ['purchase_date'])
    df['play'] = df.playtime_forever.apply(classify)
    df.eval('total_reviews = total_positive_reviews + total_negative_reviews ' , inplace=True)
    df.eval('positive_review_rate = total_positive_reviews / total_reviews ' , inplace=True)
    df['release_date'] = pd.to_datetime(df['release_date'])
    def extract_data(df, column):
        df[column+"year"] = df[column].apply(lambda x:x.year)
        df[column+'month'] = df[column].apply(lambda x: x.month)
    extract_data(df, 'purchase_date')
    extract_data(df, 'release_date')
    df['time_span'] = df.purchase_date-df.release_date
    missing_df = df.isnull().sum(axis=0).reset_index()
    missing_df.columns = ['variable', 'missing values']
    missing_df['filling factor (%)']=(df.shape[0]-missing_df['missing values'])/df.shape[0]*100
    missing_df.sort_values('filling factor (%)').reset_index(drop = True)
    df.fillna(1,inplace = True)
    df['time_span'] = df['time_span'].astype('timedelta64[D]').astype(int) 
    c = df["genres"].str.get_dummies(",") 
    df = pd.concat([df,c],axis=1,ignore_index=False)
    return df

# %%
df = preprocess('train.csv')
list_train = df.columns.values.tolist()
print(list_train)
# Out:
# ['id', 'playtime_forever', 'is_free', 'price', 'genres', 'categories', 'tags', 'purchase_date', 'release_date', 'total_positive_reviews', 'total_negative_reviews', 'play', 'total_reviews', 'positive_review_rate', 'purchase_dateyear', 'purchase_datemonth', 'release_dateyear', 'release_datemonth', 'time_span', 'Action', 'Adventure', 'Animation & Modeling', 'Audio Production', 'Casual', 'Design & Illustration', 'Early Access', 'Free to Play', 'Gore', 'Indie', 'Massively Multiplayer', 'Nudity', 'RPG', 'Racing', 'Sexual Content', 'Simulation', 'Sports', 'Strategy', 'Utilities', 'Violent']
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.

# %%
# list_train = df.columns.values.tolist()
del list_train[0:2],list_train[2:10]

# %%
X = np.array(df[list_train])
Y = np.array(df['play'])
Y = Y.reshape(len(Y), 1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
m = 0
for i in range(1,10):
    for j in range(1,10):
        clf = tree.DecisionTreeClassifier(max_depth=i,max_features = j,random_state=1)
        clf = clf.fit(X_train, Y_train)
        result = clf.predict(X_test)
#        print(result)
#        print(Y_test)
        s = 0
        for k in range(len(result)):
            if result[k] == Y_test[k]:
                s+=1
        r = s/len(result)
#        print(r)
        if r>m:
            m = r
            i_best = i
            j_best = j
print(m)
print(i_best)
print(j_best)
# Out:
# 0.6296296296296297
# 6
# 7

# %%
clf = tree.DecisionTreeClassifier(max_depth=i_best,max_features = j_best,random_state=1)
clf = clf.fit(X_train, Y_train)
result = clf.predict(X_test)

# %%
r = export_text(clf, feature_names=list_train)
print(r)
# Out:
# |--- total_reviews <= 4486.00
# |   |--- RPG <= 0.50
# |   |   |--- purchase_dateyear <= 2017.50
# |   |   |   |--- Adventure <= 0.50
# |   |   |   |   |--- purchase_dateyear <= 2015.50
# |   |   |   |   |   |--- release_datemonth <= 9.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- release_datemonth >  9.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- purchase_dateyear >  2015.50
# |   |   |   |   |   |--- release_dateyear <= 2013.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- release_dateyear >  2013.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Adventure >  0.50
# |   |   |   |   |--- time_span <= 1484.50
# |   |   |   |   |   |--- positive_review_rate <= 0.76
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- positive_review_rate >  0.76
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- time_span >  1484.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- purchase_dateyear >  2017.50
# |   |   |   |--- Simulation <= 0.50
# |   |   |   |   |--- release_datemonth <= 8.50
# |   |   |   |   |   |--- purchase_datemonth <= 11.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- purchase_datemonth >  11.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- release_datemonth >  8.50
# |   |   |   |   |   |--- price <= 3450.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- price >  3450.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Simulation >  0.50
# |   |   |   |   |--- is_free <= 0.50
# |   |   |   |   |   |--- Indie <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Indie >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- is_free >  0.50
# |   |   |   |   |   |--- class: 1
# |   |--- RPG >  0.50
# |   |   |--- purchase_dateyear <= 2017.50
# |   |   |   |--- time_span <= 187.00
# |   |   |   |   |--- is_free <= 0.50
# |   |   |   |   |   |--- release_dateyear <= 2014.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- release_dateyear >  2014.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- is_free >  0.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- time_span >  187.00
# |   |   |   |   |--- total_reviews <= 3812.50
# |   |   |   |   |   |--- total_reviews <= 409.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- total_reviews >  409.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total_reviews >  3812.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- purchase_dateyear >  2017.50
# |   |   |   |--- Casual <= 0.50
# |   |   |   |   |--- purchase_dateyear <= 2018.50
# |   |   |   |   |   |--- total_reviews <= 1635.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- total_reviews >  1635.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- purchase_dateyear >  2018.50
# |   |   |   |   |   |--- time_span <= 423.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- time_span >  423.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Casual >  0.50
# |   |   |   |   |--- class: 1
# |--- total_reviews >  4486.00
# |   |--- price <= 6200.00
# |   |   |--- RPG <= 0.50
# |   |   |   |--- Strategy <= 0.50
# |   |   |   |   |--- Simulation <= 0.50
# |   |   |   |   |   |--- time_span <= 129.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- time_span >  129.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Simulation >  0.50
# |   |   |   |   |   |--- time_span <= 872.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- time_span >  872.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Strategy >  0.50
# |   |   |   |   |--- positive_review_rate <= 0.94
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- positive_review_rate >  0.94
# |   |   |   |   |   |--- purchase_dateyear <= 2017.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- purchase_dateyear >  2017.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- RPG >  0.50
# |   |   |   |--- positive_review_rate <= 0.87
# |   |   |   |   |--- Simulation <= 0.50
# |   |   |   |   |   |--- total_reviews <= 120257.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- total_reviews >  120257.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- Simulation >  0.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- positive_review_rate >  0.87
# |   |   |   |   |--- total_reviews <= 122488.50
# |   |   |   |   |   |--- time_span <= 214.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- time_span >  214.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total_reviews >  122488.50
# |   |   |   |   |   |--- class: 2
# |   |--- price >  6200.00
# |   |   |--- release_dateyear <= 2017.50
# |   |   |   |--- purchase_dateyear <= 2017.50
# |   |   |   |   |--- total_reviews <= 48959.00
# |   |   |   |   |   |--- total_reviews <= 8565.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- total_reviews >  8565.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- total_reviews >  48959.00
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- purchase_dateyear >  2017.50
# |   |   |   |   |--- total_reviews <= 114499.50
# |   |   |   |   |   |--- Simulation <= 0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Simulation >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- total_reviews >  114499.50
# |   |   |   |   |   |--- total_reviews <= 319878.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- total_reviews >  319878.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- release_dateyear >  2017.50
# |   |   |   |--- price <= 12700.00
# |   |   |   |   |--- positive_review_rate <= 0.80
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- positive_review_rate >  0.80
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- price >  12700.00
# |   |   |   |   |--- class: 2

# %%
s = 0
for i in range(len(result)):
    if result[i] == Y_test[i]:
        s+=1
print(s/len(result))
# Out:
# 0.6296296296296297

# %%
df_new1 = df.loc[df["play"] == 1]
# c = df_new1["genres"].str.get_dummies(",") 
# df_new1 = pd.concat([df_new1,c],axis=1,ignore_index=False)
# list = df_new1.columns.values.tolist()
# del list[0:2],list[2:10]

# %%
X = np.array(df_new1[list_train])
Y = np.array(df_new1['playtime_forever'])
Y = Y.reshape(len(Y), 1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)
score_min = 10000
for pol_order in range(1, 3):
    for alpha in range(0, 20, 2):
        ridgereg = Ridge(alpha = alpha/10, normalize=True)
        poly = PolynomialFeatures(degree = pol_order)
        regr = linear_model.LinearRegression()
        X_ = poly.fit_transform(X_train)
        ridgereg.fit(X_, Y_train)
        
        X_ = poly.fit_transform(X_test)
        result = ridgereg.predict(X_)
        score = metrics.mean_squared_error(result, Y_test)
        
        if score < score_min:
            score_min = score
            parameters = [alpha, pol_order]

        print("n={} alpha={} , MSE = {:<0.5}".format(pol_order, alpha/10, score))
# Out:
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:189: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# n=1 alpha=0.0 , MSE = 2.7456e+05
# n=1 alpha=0.2 , MSE = 7513.7
# n=1 alpha=0.4 , MSE = 4834.4
# n=1 alpha=0.6 , MSE = 3483.8
# n=1 alpha=0.8 , MSE = 2678.0
# n=1 alpha=1.0 , MSE = 2145.9
# n=1 alpha=1.2 , MSE = 1770.2
# n=1 alpha=1.4 , MSE = 1491.9
# n=1 alpha=1.6 , MSE = 1278.6
# n=1 alpha=1.8 , MSE = 1110.4
# n=2 alpha=0.0 , MSE = 2.1712e+06
# n=2 alpha=0.2 , MSE = 3591.1
# n=2 alpha=0.4 , MSE = 2482.8
# n=2 alpha=0.6 , MSE = 1927.8
# n=2 alpha=0.8 , MSE = 1576.4
# n=2 alpha=1.0 , MSE = 1328.8
# n=2 alpha=1.2 , MSE = 1143.4
# n=2 alpha=1.4 , MSE = 999.06
# n=2 alpha=1.6 , MSE = 883.45
# n=2 alpha=1.8 , MSE = 788.89

# %%
ridgereg1 = Ridge(alpha = parameters[0], normalize=True)
poly1 = PolynomialFeatures(degree = parameters[1])
X_ = poly1.fit_transform(X)
ridgereg1.fit(X_, Y)
result = ridgereg1.predict(X_)
score = metrics.mean_squared_error(result, Y,multioutput='raw_values')
print(score)
# Out:
# [3.36041666]

# %%
len(X_)
# Out:
# 164

# %%
df_new2 = df.loc[df["play"] == 2]
# c = df_new2["genres"].str.get_dummies(",") 
# df_new2 = pd.concat([df_new2,c],axis=1,ignore_index=False)
# list = df_new2.columns.values.tolist()
# del list[0:2],list[2:12]
X = np.array(df_new2[list_train])
Y = np.array(df_new2['playtime_forever'])
Y = Y.reshape(len(Y), 1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)
score_min = 10000
for pol_order in range(1, 3):
    for alpha in range(0, 20, 2):
        ridgereg = Ridge(alpha = alpha/10, normalize=True)
        poly = PolynomialFeatures(degree = pol_order)
        regr = linear_model.LinearRegression()
        X_ = poly.fit_transform(X_train)
        ridgereg.fit(X_, Y_train)
        
        X_ = poly.fit_transform(X_test)
        result = ridgereg.predict(X_)
        score = metrics.mean_squared_error(result, Y_test)
        
        if score < score_min:
            score_min = score
            parameters = [alpha, pol_order]

        print("n={} alpha={} , MSE = {:<0.5}".format(pol_order, alpha/10, score))
# Out:
# n=1 alpha=0.0 , MSE = 1.6323e+04
# n=1 alpha=0.2 , MSE = 530.07
# n=1 alpha=0.4 , MSE = 369.01
# n=1 alpha=0.6 , MSE = 350.31
# n=1 alpha=0.8 , MSE = 362.44
# n=1 alpha=1.0 , MSE = 382.2
# n=1 alpha=1.2 , MSE = 402.85
# n=1 alpha=1.4 , MSE = 422.25
# n=1 alpha=1.6 , MSE = 439.81
# n=1 alpha=1.8 , MSE = 455.45
# n=2 alpha=0.0 , MSE = 2381.0
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:189: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\ridge.py:189: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# n=2 alpha=0.2 , MSE = 2132.4
# n=2 alpha=0.4 , MSE = 1928.0
# n=2 alpha=0.6 , MSE = 1755.8
# n=2 alpha=0.8 , MSE = 1608.5
# n=2 alpha=1.0 , MSE = 1481.1
# n=2 alpha=1.2 , MSE = 1369.9
# n=2 alpha=1.4 , MSE = 1272.1
# n=2 alpha=1.6 , MSE = 1185.7
# n=2 alpha=1.8 , MSE = 1108.9

# %%
ridgereg2 = Ridge(alpha = parameters[0], normalize=True)
poly2 = PolynomialFeatures(degree = parameters[1])
X_ = poly2.fit_transform(X)
ridgereg2.fit(X_, Y)
result = ridgereg2.predict(X_)
score = metrics.mean_squared_error(result, Y)
print(score)
# Out:
# 621.5641361799593

# %%
def preprocess_test(filename):
    df = pd.read_csv(filename,parse_dates = ['purchase_date'])
    df.eval('total_reviews = total_positive_reviews + total_negative_reviews ' , inplace=True)
    df.eval('positive_review_rate = total_positive_reviews / total_reviews ' , inplace=True)
    df['release_date'] = pd.to_datetime(df['release_date'])
    def extract_data(df, column):
        df[column+"year"] = df[column].apply(lambda x:x.year)
        df[column+'month'] = df[column].apply(lambda x: x.month)
    extract_data(df, 'purchase_date')
    extract_data(df, 'release_date')
    df['time_span'] = df.purchase_date-df.release_date
    missing_df = df.isnull().sum(axis=0).reset_index()
    missing_df.columns = ['variable', 'missing values']
    missing_df['filling factor (%)']=(df.shape[0]-missing_df['missing values'])/df.shape[0]*100
    missing_df.sort_values('filling factor (%)').reset_index(drop = True)
    df.fillna(1,inplace = True)
    df['time_span'] = df['time_span'].astype('timedelta64[D]').astype(int) 
    c = df["genres"].str.get_dummies(",") 
    df = pd.concat([df,c],axis=1,ignore_index=False)
    return df

# %%
df = preprocess_test('test.csv')
list = df.columns.values.tolist()
del list[0],list[2:9]
print(list)
# Out:
# ['is_free', 'price', 'total_reviews', 'positive_review_rate', 'purchase_dateyear', 'purchase_datemonth', 'release_dateyear', 'release_datemonth', 'time_span', 'Action', 'Adventure', 'Casual', 'Early Access', 'Free to Play', 'Gore', 'Indie', 'Massively Multiplayer', 'Nudity', 'RPG', 'Simulation', 'Sports', 'Strategy', 'Violent']
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.
#   app.launch_new_instance()

# %%
list_to_add = [a for a in list_train if a not in list]
print(list_to_add)
# Out:
# ['Animation & Modeling', 'Audio Production', 'Design & Illustration', 'Racing', 'Sexual Content', 'Utilities']

# %%
for i in list_to_add:
    df[i] = 0

# %%
X = np.array(df[list_train])

# %%
df['playtime_forever'] = clf.predict(X)

# %%
df_poly1 = df.loc[df['playtime_forever'] == 1]
# c = df_new1["genres"].str.get_dummies(",") 
# df_new1 = pd.concat([df_new1,c],axis=1,ignore_index=False)
# list = df_new1.columns.values.tolist()
# del list[0:2],list[2:10]

# %%
df_poly1
# Out:
#     id  is_free  price                                         genres  \
# 4    4    False   3400                               Action,Adventure
# 5    5    False   6800                            Adventure,Indie,RPG
# 12  12    False   4800                         Action,Adventure,Indie
# 13  13    False   4200                         Adventure,Casual,Indie
# 14  14    False   6800                                         Action
# 15  15     True      0  Massively Multiplayer,Simulation,Early Access
# 17  17    False   7800                            Action,Casual,Indie
# 18  18    False   6800                     Action,Adventure,Indie,RPG
# 23  23    False   7500              Adventure,Casual,Indie,Simulation
# 27  27    False   6800                         Adventure,Casual,Indie
# 32  32    False   7800                                   Action,Indie
# 33  33    False   6800                         Adventure,Casual,Indie
# 34  34    False   5900                                            RPG
# 36  36    False   3600                          Action,Indie,Strategy
# 37  37    False   4800              Action,Adventure,Casual,Indie,RPG
# 39  39    False   1999                                         Action
# 44  44    False   7800                                Adventure,Indie
# 45  45    False   7000                    Adventure,Simulation,Sports
# 49  49     True      0                            Action,Free to Play
# 50  50     True      0                            Action,Free to Play
# 54  54    False   5000                                   RPG,Strategy
# 56  56    False   1100                  Nudity,Adventure,Casual,Indie
# 59  59    False   3600                         Adventure,RPG,Strategy
# 63  63    False  24800                           Action,Adventure,RPG
# 65  65    False   3100                         Adventure,Casual,Indie
# 66  66     True      0                                   Free to Play
# 68  68    False   1500                                   Action,Indie
# 72  72    False   3600                            Adventure,Indie,RPG
# 74  74    False   2800                Adventure,Casual,Indie,Strategy
# 75  75    False   4800              Action,Adventure,Casual,Indie,RPG
# 77  77    False   4800                         Action,Adventure,Indie
# 78  78    False    700                            Adventure,Indie,RPG
# 81  81    False  11900                         Adventure,Casual,Indie
# 85  85    False   5000                                         Action
#
#                                            categories  \
# 4   Single-player,Co-op,Steam Achievements,Full co...
# 5   Single-player,Steam Achievements,Full controll...
# 12  Single-player,Steam Achievements,Full controll...
# 13  Single-player,Steam Achievements,Full controll...
# 14  Single-player,Steam Achievements,Full controll...
# 15  Single-player,Online Multi-Player,MMO,Online C...
# 17  Single-player,Steam Achievements,Full controll...
# 18  Single-player,Steam Achievements,Full controll...
# 23                                      Single-player
# 27  Single-player,Steam Achievements,Steam Trading...
# 32  Single-player,Steam Achievements,SteamVR Colle...
# 33  Single-player,Steam Achievements,VR Support,St...
# 34                          Single-player,Steam Cloud
# 36  Single-player,Steam Achievements,Steam Trading...
# 37  Single-player,Multi-player,Online Multi-Player...
# 39           Single-player,Partial Controller Support
# 44  Single-player,Steam Achievements,Steam Trading...
# 45  Single-player,Multi-player,Steam Achievements,...
# 49  Single-player,Multi-player,Online Multi-Player...
# 50  Single-player,Multi-player,Online Multi-Player...
# 54  Single-player,Steam Achievements,Full controll...
# 56  Single-player,Steam Achievements,Steam Trading...
# 59       Single-player,Steam Achievements,Steam Cloud
# 63  Single-player,Steam Achievements,Steam Trading...
# 65  Single-player,Steam Achievements,Steam Trading...
# 66  Single-player,VR Support,SteamVR Collectibles,...
# 68  Single-player,Steam Achievements,Full controll...
# 72  Single-player,Steam Achievements,Steam Trading...
# 74  Single-player,Steam Achievements,Steam Trading...
# 75  Single-player,Multi-player,Online Multi-Player...
# 77              Single-player,Full controller support
# 78  Single-player,Steam Achievements,Steam Trading...
# 81  Single-player,Steam Achievements,Full controll...
# 85  Single-player,Steam Achievements,Full controll...
#
#                                                  tags        purchase_date  \
# 4   Open World,Action,Comedy,Co-op,Third-Person Sh...  2017-02-24 00:00:00
# 5   Indie,Adventure,RPG,Interactive Fiction,Story ...  2018-06-03 00:00:00
# 12  Survival,Adventure,Great Soundtrack,Indie,Craf...                    1
# 13  Adventure,First-Person,Parkour,Singleplayer,In...  2017-06-28 00:00:00
# 14  Post-apocalyptic,Atmospheric,FPS,Action,Story ...  2017-06-12 00:00:00
# 15  Early Access,Early Access,VR,Simulation,Massiv...  2018-09-01 00:00:00
# 17  Action,Great Soundtrack,Indie,Casual,On-Rails ...  2017-12-01 00:00:00
# 18  Underwater,Action,Adventure,RPG,Indie,Steampun...  2017-12-11 00:00:00
# 23  VR,Simulation,Adventure,Casual,Indie,Underwate...  2017-11-19 00:00:00
# 27  Adventure,Puzzle,Point & Click,Retro,1990's,Cu...  2017-10-25 00:00:00
# 32  VR,Action,Shooter,Indie,Bullet Time,FPS,First-...  2017-12-27 00:00:00
# 33  Adventure,Indie,VR,First-Person,Great Soundtra...  2017-12-22 00:00:00
# 34  RPG,Open World,Fantasy,Classic,Great Soundtrac...  2016-11-04 00:00:00
# 36  Stealth,Puzzle,Indie,2D,Pixel Graphics,Comedy,...  2016-11-03 00:00:00
# 37  Co-op,Action,Multiplayer,Adventure,Local Co-Op...  2017-06-29 00:00:00
# 39  Action,FPS,Sci-fi,Shooter,Singleplayer,Multipl...  2018-07-02 00:00:00
# 44  Adventure,Puzzle,Indie,First-Person,Exploratio...  2017-10-25 00:00:00
# 45  Hunting,Open World,Multiplayer,Simulation,Adve...                    1
# 49  PvP,Multiplayer,Competitive,MOBA,Action,Free t...  2016-10-17 00:00:00
# 50  Free to Play,Co-op,Multiplayer,Top-Down Shoote...  2017-09-01 00:00:00
# 54  Anime,JRPG,Female Protagonist,Cute,RPG,Singlep...  2019-04-22 00:00:00
# 56  Visual Novel,Dating Sim,Anime,Sexual Content,N...  2017-09-21 00:00:00
# 59  FMV,Detective,Adventure,Mystery,Point & Click,...  2018-07-03 00:00:00
# 63  Open World,Assassin,Action,RPG,Parkour,Stealth...  2017-12-10 00:00:00
# 65  Indie,Platformer,Adventure,Puzzle,Casual,Puzzl...  2017-03-25 00:00:00
# 66  Free to Play,VR,Action,Singleplayer,First-Pers...  2017-11-18 00:00:00
# 68  Indie,Action,Difficult,Arcade,Music,Great Soun...  2017-01-06 00:00:00
# 72  Story Rich,Great Soundtrack,Pixel Graphics,Ind...  2018-11-22 00:00:00
# 74  Pixel Graphics,Casual,Strategy,Puzzle,Gore,Vio...  2017-11-22 00:00:00
# 75  Sandbox,Survival,Adventure,Space,Crafting,Indi...  2017-10-12 00:00:00
# 77  Adventure,Atmospheric,Story Rich,Controller,In...  2017-03-23 00:00:00
# 78  Adventure,Crime,Indie,RPGMaker,Atmospheric,Sto...  2018-05-14 00:00:00
# 81  Point & Click,Choices Matter,Medieval,Visual N...  2017-12-13 00:00:00
# 85  Western,FPS,Action,Story Rich,Bullet Time,Shoo...  2018-03-23 00:00:00
#
#    release_date  total_positive_reviews  total_negative_reviews  ...  Sports  \
# 4    2013-08-22                 40344.0                  3708.0  ...       0
# 5    2018-02-28                   387.0                    81.0  ...       0
# 12   2016-02-24                     1.0                     1.0  ...       0
# 13   2014-05-28                  9348.0                   739.0  ...       0
# 14   2014-08-27                 21249.0                  4852.0  ...       0
# 15   2017-04-12                     0.0                     0.0  ...       0
# 17   2017-08-09                   572.0                    54.0  ...       0
# 18   2017-02-02                   530.0                   277.0  ...       0
# 23   2016-04-05                   869.0                   156.0  ...       0
# 27   2016-03-24                  1476.0                    81.0  ...       0
# 32   2017-05-25                  2446.0                   277.0  ...       0
# 33   2016-04-05                   759.0                   153.0  ...       0
# 34   2009-06-16                  7790.0                   464.0  ...       0
# 36   2013-06-03                  8000.0                   221.0  ...       0
# 37   2012-09-26                 38867.0                  1506.0  ...       0
# 39   2011-03-22                  4411.0                   886.0  ...       0
# 44   2016-11-28                  1101.0                   104.0  ...       0
# 45   2017-02-16                     1.0                     1.0  ...       1
# 49   2017-11-08                 18299.0                  2616.0  ...       0
# 50   2017-04-20                     0.0                     0.0  ...       0
# 54   2015-01-29                  8070.0                   415.0  ...       0
# 56   2017-09-20                 11441.0                  1132.0  ...       0
# 59   2015-07-10                  1454.0                    60.0  ...       0
# 63   2017-10-26                 29399.0                  5761.0  ...       0
# 65   2013-10-25                  1780.0                   211.0  ...       0
# 66   2016-04-05                   112.0                     7.0  ...       0
# 68   2016-05-27                   671.0                    85.0  ...       0
# 72   2017-12-14                  6556.0                   135.0  ...       0
# 74   2017-11-06                  1941.0                   186.0  ...       0
# 75   2016-07-22                 89477.0                  6271.0  ...       0
# 77   2013-09-03                 27041.0                  1526.0  ...       0
# 78   2016-05-10                   270.0                    37.0  ...       0
# 81   2017-08-15                   935.0                    71.0  ...       0
# 85   2013-05-22                  9334.0                   516.0  ...       0
#
#     Strategy  Violent  Animation & Modeling  Audio Production  \
# 4          0        0                     0                 0
# 5          0        0                     0                 0
# 12         0        0                     0                 0
# 13         0        0                     0                 0
# 14         0        0                     0                 0
# 15         0        0                     0                 0
# 17         0        0                     0                 0
# 18         0        0                     0                 0
# 23         0        0                     0                 0
# 27         0        0                     0                 0
# 32         0        0                     0                 0
# 33         0        0                     0                 0
# 34         0        0                     0                 0
# 36         1        0                     0                 0
# 37         0        0                     0                 0
# 39         0        0                     0                 0
# 44         0        0                     0                 0
# 45         0        0                     0                 0
# 49         0        0                     0                 0
# 50         0        0                     0                 0
# 54         1        0                     0                 0
# 56         0        0                     0                 0
# 59         1        0                     0                 0
# 63         0        0                     0                 0
# 65         0        0                     0                 0
# 66         0        0                     0                 0
# 68         0        0                     0                 0
# 72         0        0                     0                 0
# 74         1        0                     0                 0
# 75         0        0                     0                 0
# 77         0        0                     0                 0
# 78         0        0                     0                 0
# 81         0        0                     0                 0
# 85         0        0                     0                 0
#
#     Design & Illustration  Racing  Sexual Content  Utilities  playtime_forever
# 4                       0       0               0          0                 1
# 5                       0       0               0          0                 1
# 12                      0       0               0          0                 1
# 13                      0       0               0          0                 1
# 14                      0       0               0          0                 1
# 15                      0       0               0          0                 1
# 17                      0       0               0          0                 1
# 18                      0       0               0          0                 1
# 23                      0       0               0          0                 1
# 27                      0       0               0          0                 1
# 32                      0       0               0          0                 1
# 33                      0       0               0          0                 1
# 34                      0       0               0          0                 1
# 36                      0       0               0          0                 1
# 37                      0       0               0          0                 1
# 39                      0       0               0          0                 1
# 44                      0       0               0          0                 1
# 45                      0       0               0          0                 1
# 49                      0       0               0          0                 1
# 50                      0       0               0          0                 1
# 54                      0       0               0          0                 1
# 56                      0       0               0          0                 1
# 59                      0       0               0          0                 1
# 63                      0       0               0          0                 1
# 65                      0       0               0          0                 1
# 66                      0       0               0          0                 1
# 68                      0       0               0          0                 1
# 72                      0       0               0          0                 1
# 74                      0       0               0          0                 1
# 75                      0       0               0          0                 1
# 77                      0       0               0          0                 1
# 78                      0       0               0          0                 1
# 81                      0       0               0          0                 1
# 85                      0       0               0          0                 1
#
# [34 rows x 38 columns]

# %%
X = np.array(df_poly1[list_train])

# %%
X_ = poly1.fit_transform(X)
df_poly1['playtime_forever'] = ridgereg1.predict(X_)
# Out:
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_poly1.head(10)
# Out:
#     id  is_free  price                                         genres  \
# 4    4    False   3400                               Action,Adventure
# 5    5    False   6800                            Adventure,Indie,RPG
# 12  12    False   4800                         Action,Adventure,Indie
# 13  13    False   4200                         Adventure,Casual,Indie
# 14  14    False   6800                                         Action
# 15  15     True      0  Massively Multiplayer,Simulation,Early Access
# 17  17    False   7800                            Action,Casual,Indie
# 18  18    False   6800                     Action,Adventure,Indie,RPG
# 23  23    False   7500              Adventure,Casual,Indie,Simulation
# 27  27    False   6800                         Adventure,Casual,Indie
#
#                                            categories  \
# 4   Single-player,Co-op,Steam Achievements,Full co...
# 5   Single-player,Steam Achievements,Full controll...
# 12  Single-player,Steam Achievements,Full controll...
# 13  Single-player,Steam Achievements,Full controll...
# 14  Single-player,Steam Achievements,Full controll...
# 15  Single-player,Online Multi-Player,MMO,Online C...
# 17  Single-player,Steam Achievements,Full controll...
# 18  Single-player,Steam Achievements,Full controll...
# 23                                      Single-player
# 27  Single-player,Steam Achievements,Steam Trading...
#
#                                                  tags        purchase_date  \
# 4   Open World,Action,Comedy,Co-op,Third-Person Sh...  2017-02-24 00:00:00
# 5   Indie,Adventure,RPG,Interactive Fiction,Story ...  2018-06-03 00:00:00
# 12  Survival,Adventure,Great Soundtrack,Indie,Craf...                    1
# 13  Adventure,First-Person,Parkour,Singleplayer,In...  2017-06-28 00:00:00
# 14  Post-apocalyptic,Atmospheric,FPS,Action,Story ...  2017-06-12 00:00:00
# 15  Early Access,Early Access,VR,Simulation,Massiv...  2018-09-01 00:00:00
# 17  Action,Great Soundtrack,Indie,Casual,On-Rails ...  2017-12-01 00:00:00
# 18  Underwater,Action,Adventure,RPG,Indie,Steampun...  2017-12-11 00:00:00
# 23  VR,Simulation,Adventure,Casual,Indie,Underwate...  2017-11-19 00:00:00
# 27  Adventure,Puzzle,Point & Click,Retro,1990's,Cu...  2017-10-25 00:00:00
#
#    release_date  total_positive_reviews  total_negative_reviews  ...  Sports  \
# 4    2013-08-22                 40344.0                  3708.0  ...       0
# 5    2018-02-28                   387.0                    81.0  ...       0
# 12   2016-02-24                     1.0                     1.0  ...       0
# 13   2014-05-28                  9348.0                   739.0  ...       0
# 14   2014-08-27                 21249.0                  4852.0  ...       0
# 15   2017-04-12                     0.0                     0.0  ...       0
# 17   2017-08-09                   572.0                    54.0  ...       0
# 18   2017-02-02                   530.0                   277.0  ...       0
# 23   2016-04-05                   869.0                   156.0  ...       0
# 27   2016-03-24                  1476.0                    81.0  ...       0
#
#     Strategy  Violent  Animation & Modeling  Audio Production  \
# 4          0        0                     0                 0
# 5          0        0                     0                 0
# 12         0        0                     0                 0
# 13         0        0                     0                 0
# 14         0        0                     0                 0
# 15         0        0                     0                 0
# 17         0        0                     0                 0
# 18         0        0                     0                 0
# 23         0        0                     0                 0
# 27         0        0                     0                 0
#
#     Design & Illustration  Racing  Sexual Content  Utilities  playtime_forever
# 4                       0       0               0          0          2.122789
# 5                       0       0               0          0          2.130266
# 12                      0       0               0          0          2.212423
# 13                      0       0               0          0          1.710433
# 14                      0       0               0          0          1.890349
# 15                      0       0               0          0          1.353669
# 17                      0       0               0          0          1.576330
# 18                      0       0               0          0          2.153276
# 23                      0       0               0          0          1.419652
# 27                      0       0               0          0          1.766025
#
# [10 rows x 38 columns]

# %%
df_poly2 = df.loc[df['playtime_forever'] == 2]
X = np.array(df_poly2[list_train])
X_ = poly2.fit_transform(X)
df_poly2['playtime_forever'] = ridgereg2.predict(X_)
# Out:
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_poly2.head(10)
# Out:
#     id  is_free  price                                           genres  \
# 1    1    False  11600                        Action,Adventure,Strategy
# 31  31    False   6800                                              RPG
# 71  71    False   8800                              Simulation,Strategy
# 76  76    False   6400                                       Action,RPG
# 88  88     True      0  Action,Adventure,RPG,Simulation,Sports,Strategy
#
#                                            categories  \
# 1   Single-player,Multi-player,Online Multi-Player...
# 31  Single-player,Steam Achievements,Steam Trading...
# 71  Single-player,Steam Achievements,Steam Trading...
# 76  Single-player,Co-op,Steam Achievements,Full co...
# 88  Single-player,Multi-player,Co-op,Online Co-op,...
#
#                                                  tags        purchase_date  \
# 1   Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...  2019-07-20 00:00:00
# 31  Open World,RPG,Fantasy,Adventure,Dragons,Modda...  2016-11-05 00:00:00
# 71  City Builder,Simulation,Building,Management,St...  2017-12-07 00:00:00
# 76  FPS,Co-op,Loot,RPG,Action,Shooter,Open World,F...  2017-03-17 00:00:00
# 88  VR,RPG,Action,Sports,Simulation,Adventure,Stra...  2017-11-19 00:00:00
#
#    release_date  total_positive_reviews  total_negative_reviews  ...  Sports  \
# 1    2018-04-24                  5762.0                  2235.0  ...       0
# 31   2011-11-10                149032.0                  9466.0  ...       0
# 71   2015-03-10                 56571.0                  4989.0  ...       0
# 76   2012-09-20                121862.0                  4810.0  ...       0
# 88   2017-06-19                     5.0                     0.0  ...       1
#
#     Strategy  Violent  Animation & Modeling  Audio Production  \
# 1          1        0                     0                 0
# 31         0        0                     0                 0
# 71         1        0                     0                 0
# 76         0        0                     0                 0
# 88         1        0                     0                 0
#
#     Design & Illustration  Racing  Sexual Content  Utilities  playtime_forever
# 1                       0       0               0          0         36.021651
# 31                      0       0               0          0         36.073362
# 71                      0       0               0          0         42.440891
# 76                      0       0               0          0         31.429756
# 88                      0       0               0          0         38.230379
#
# [5 rows x 38 columns]

# %%
df.playtime_forever[df['playtime_forever']==1]=df_poly1['playtime_forever']
df.playtime_forever[df['playtime_forever']==2]=df_poly2['playtime_forever']
# Out:
# c:\users\qing\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
final = df[['id', 'playtime_forever']]

# %%
final
# Out:
#     id  playtime_forever
# 0    0          0.000000
# 1    1         36.021651
# 2    2          0.000000
# 3    3          0.000000
# 4    4          2.122789
# 5    5          2.130266
# 6    6          0.000000
# 7    7          0.000000
# 8    8          0.000000
# 9    9          0.000000
# 10  10          0.000000
# 11  11          0.000000
# 12  12          2.212423
# 13  13          1.710433
# 14  14          1.890349
# 15  15          1.353669
# 16  16          0.000000
# 17  17          1.576330
# 18  18          2.153276
# 19  19          0.000000
# 20  20          0.000000
# 21  21          0.000000
# 22  22          0.000000
# 23  23          1.419652
# 24  24          0.000000
# 25  25          0.000000
# 26  26          0.000000
# 27  27          1.766025
# 28  28          0.000000
# 29  29          0.000000
# ..  ..               ...
# 60  60          0.000000
# 61  61          0.000000
# 62  62          0.000000
# 63  63          2.271727
# 64  64          0.000000
# 65  65          1.602655
# 66  66          1.681767
# 67  67          0.000000
# 68  68          1.867685
# 69  69          0.000000
# 70  70          0.000000
# 71  71         42.440891
# 72  72          2.016301
# 73  73          0.000000
# 74  74          1.534055
# 75  75          2.054785
# 76  76         31.429756
# 77  77          1.994856
# 78  78          2.073170
# 79  79          0.000000
# 80  80          0.000000
# 81  81          1.730276
# 82  82          0.000000
# 83  83          0.000000
# 84  84          0.000000
# 85  85          1.924812
# 86  86          0.000000
# 87  87          0.000000
# 88  88         38.230379
# 89  89          0.000000
#
# [90 rows x 2 columns]

# %%
final.to_csv('samplesubmission.csv',index=False)
